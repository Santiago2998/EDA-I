# %% [markdown]
# CONCLUSIÓN
#
# Con base en los resultados obtenidos, se puede concluir un cumplimiento adecuado de los objetivos, ya que con ayuda de algunas funciones que ya se encuentran definidas en Python, se pudieron hacer diferentes operaciones algebraicas. Además de poder crear, leer y escribir dentro de archivos y hacer las estructuras de pila y cola de una manera mucho más sencilla.
