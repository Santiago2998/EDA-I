# %% [markdown]
# **Ejercicio 1**
#
# Definir vairables, aplicar operaciones, mostrar resultado y mostrar tipo de dato

# %%
dato = 10
valor = 15
total = dato + valor
print("Suma es: ",total)
print(type(total))

# %% [markdown]
# **Ejercicio 2**
#
# Todas las operaciones aritméticas pidiéndole al usuario dos valores

# %%
valor1 = int(input("Ingresa un primer valor: "))
valor2 = int(input("Ingresa un segundo valor: "))

print("La suma es: ", valor1 + valor2)
print("La resta es: ",  valor1 - valor2)
print("La multiplicación es: ", valor1 * valor2)
print("La división es: ", valor1 / valor2)

valor_base = int(input("Ingresa la base del numero: "))
valor_exponente = int(input("Ingresa el exponente del numero: "))
print("El resultado de la potencia es: ", valor_base**valor_exponente)

# %% [markdown]
# **Ejercicio 3**
#
# Probar las funciones trigonométricas

# %%
import math

rSeno = math.sin(1)
rCoseno = math.cos(1)
rTangente = math.tan(1)

print("El seno de 1 radian es: ", rSeno)
print("El coseno de 1 radian es: ", rCoseno)
print("El tangente de 1 radian es: ", rTangente)

# %% [markdown]
# **Ejercicio 4**
#
# Leer todo un archivo y escribir en el mismo

# %%
f = open("archivoP9.txt", "w")
fileCreate = f.write("Este es el contenido del archivo que recién se creó")
f.close()

f1 = open("archivoP9.txt", "r")
file1 = f1.read()
f.close()
print(file1)

# %% [markdown]
# **Ejercicio 5**
#
# Considerar textos de triple comillas con salto de línea y utilizar replace a consideración

# %%
frase = """Estoy escribiendo texto en triple comillas para modificar la palabra: 
texto, por informacion"""

print("La frase original es: ", frase)

NuevaPalabra = frase.replace("texto", "informacion")
print("La nueva palabra es: ", NuevaPalabra)

# %% [markdown]
# **Ejercicio 6**
#
# Tomar fragmentos de caracteres, guardarlas en variables y aplicar f-string

# %%
frase = """La frase para tomar fragmentos de char"""

parte1 = frase[0:10]
parte2 = frase[10:19]
parte3 = frase[19:38]

print(f"La Frase completa es: {frase}")
print(f"La parte 1 de la frase es: {parte1}")
print("La parte 2 de la frasse es: " + parte2)
print(f"La parte 3 de la frase es: {parte3}")

# %% [markdown]
# **Ejercicio 7**
#
# Hacer un menú de opciones y alguna de las opciones debe hacer un ciclo

# %%
print("Menu Calculadora")
print("1. Suma\n2. Resta\n3. Multiplicación\n4. División\n5. Potencia")
opcion = int(input("Selecciona una opción: "))

if (opcion == 1):
    n1 = float(input("Ingresa un valor 1: "))
    n2 = float(input("Ingresa un valor 2: "))
    suma = n1 + n2
    print(f"La suma es: {suma}")
elif (opcion == 2):
    n1 = float(input("Ingresa un valor 1: "))
    n2 = float(input("Ingresa un valor 2: "))
    resta = n1 - n2
    print(f"La resta es: {resta}")
elif (opcion == 3):
    n1 = float(input("Ingresa un valor 1: "))
    n2 = float(input("Ingresa un valor 2: "))
    multip = n1 * n2
    print(f"La multiplicación es: {multip}")
elif (opcion == 4):
    n1 = float(input("Ingresa un valor 1: "))
    n2 = float(input("Ingresa un valor 2: "))
    division = n1 / n2
    print(f"La division es: {division}")
elif (opcion == 5):
    respuesta = int(input("Cuantas veces quieres hacer la potencia? "))
    contador = 0
    while (contador != respuesta):
        n1 = float(input("Ingresa la base: "))
        n2 = float(input("Ingresa el exponente: "))
        potencia = n1 ** n2
        print(f"La potencia es: {potencia}")
        contador += 1
else:
    print("No existe esa opción")

# %% [markdown]
# **Ejercicio 8**
#
# Hacer todas las estructuras de datos (Pila, cola simple, lista)

# %% [markdown]
# Pila

# %%
pila = []

pila.append("Dato 1")
pila.append("Dato 2")
pila.append("Dato 3")

ultimo = pila.pop() 

print(f"Salió: {ultimo}") 
print(f"Pila actual: {pila}")

# %% [markdown]
# Cola simple

# %%
from collections import deque

cola = deque()

cola.append("Persona A")
cola.append("Persona B")
print(f"La cola simple es: {cola}")

primero = cola.popleft() 

print(f"Atendiendo a: {primero}")
print(f"Quedan en fila: {list(cola)}")

# %% [markdown]
# Lista

# %%
nombres = {1:"Alex", 2:"Beto", 3:"Carla"}

print(f"La lista es: {nombres}")
id = int(input("Ingresa un ID para mostar de la lista"))
print(f"El nombre es: " + nombres[id])

# %% [markdown]
# **Ejercicio 9**
#
# Al menú de opciones agrega a otra opción una función normal y otra de tipo lambda

# %%
# 1. Función declarada normal (con validación de seguridad)
def division_segura(a, b):
    if b == 0:
        return "Error: No se puede dividir entre cero"
    return a / b

# 2. Función Lambda (anónima y rápida)
multiplicar = lambda a, b: a * b

print("Menu Calculadora")
print("1. Suma\n2. Resta\n3. Multiplicación\n4. División\n5. Potencia")
opcion = int(input("Selecciona una opción: "))

# Operaciones comunes para evitar repetir código
if 1 <= opcion <= 4:
    n1 = float(input("Ingresa un valor 1: "))
    n2 = float(input("Ingresa un valor 2: "))

if opcion == 1:
    suma = n1 + n2
    print(f"La suma es: {suma}")

elif opcion == 2:
    resta = n1 - n2
    print(f"La resta es: {resta}")

elif opcion == 3:
    # Uso de la función Lambda
    resultado = multiplicar(n1, n2)
    print(f"La multiplicación es: {resultado}")

elif opcion == 4:
    # Uso de la función normal
    resultado = division_segura(n1, n2)
    print(f"La división es: {resultado}")

elif opcion == 5:
    respuesta = int(input("¿Cuántas veces quieres hacer la potencia? "))
    contador = 0
    while contador != respuesta:
        base = float(input("Ingresa la base: "))
        exponente = float(input("Ingresa el exponente: "))
        print(f"La potencia es: {base ** exponente}")
        contador += 1
else:
    print("No existe esa opción")
