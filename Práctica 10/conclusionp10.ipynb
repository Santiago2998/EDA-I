# %% [markdown]
# *Conclusión*
#
# Con base en los resultados obtenidos, se puede concluir un cumplimiento adecuado de los objetivos ya que, al utilizar Insertion Sort, se pudieron ordenar las materias de acuerdo con los criterios de hora y prioridad del 1 al 5. Además de revisar si hay traslapes de materias, en este caso se selecciona la materia según su prioridad y, en caso de que sean iguales, se le pregunta al usuario cuál desea conservar.
